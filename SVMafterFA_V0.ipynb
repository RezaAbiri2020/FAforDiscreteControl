# %% [markdown]
# # This is to perform SVM after Factor Analysis

# %%
# clean the memory 


# loading the library
import numpy as np
import os
import os.path
import scipy.io
from scipy.io import loadmat
#import mat73

# Experiment info 
yymmdd = '20201002'
perf_Arrow_hhmmss = list(['145058','145910','150443','151528','152108'])

# loading the mat data
for j in range(1):
    #len(perf_Arrow_hhmmss)):
    DataPath =os.path.join('E:','\Bravo1','CursorPlatform','Data',yymmdd,'GangulyServer',yymmdd,'RadialTask',perf_Arrow_hhmmss[j],'BCI_Fixed')
    datadir = os.listdir(DataPath)
    
    for k in range(1):#len(datadir)):
        print(1)
        #mat = mat73.loadmat(DataPath+'/'+datadir[k])
        
   
FileExample = loadmat('E:\BRAVO1\FAforDiscreteControl\FAWeights_20201002.mat')
# Out:
# 1

# %%
type(FileExample)
# Out:
# dict

# %%
FileExample.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'FAWeights_20201002'])

# %%
type(FileExample['FAWeights_20201002']),FileExample['FAWeights_20201002'].shape
# Out:
# (numpy.ndarray, (1, 1))

# %%
type(FileExample['FAWeights_20201002'][0][0]),FileExample['FAWeights_20201002'][0][0].shape
# Out:
# (numpy.void, ())

# %%
FileExample['FAWeights_20201002']['Target'].shape
# Out:
# (1, 1)

# %%
FileExample['FAWeights_20201002']['Target']['feature']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-c1a66cf298ba> in <module>
# ----> 1 FileExample['FAWeights_20201002']['Target']['feature']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
FileExample['FAWeights_20201002']['Target'][0,0]['feature']
# Out:
# array([[array([[array([[-3.18361667e-02,  8.16413885e-02,  5.61596366e-04, ...,
#          1.07666604e-01, -5.57580583e-02, -3.30958069e-03],
#        [-3.80551569e-02, -6.69125169e-02,  3.00682178e-02, ...,
#          1.93439409e-01,  2.04475478e-01,  1.27680104e-03],
#        [ 1.66354482e-02,  1.17791780e-01,  1.33847519e-02, ...,
#          9.93874223e-02, -4.65868875e-02,  1.29808170e-01],
#        ...,
#        [-5.60920065e-02, -3.83856238e-02,  9.46275661e-02, ...,
#          1.01229037e-01,  3.69819120e-01,  1.53683716e-03],
#        [ 7.91577523e-01,  2.63401208e-02,  1.46566811e-01, ...,
#          3.09608614e-02,  6.96543551e-02, -3.43202241e-04],
#        [ 1.62829638e-01,  2.10279543e-02,  1.88090357e-02, ...,
#          1.47184835e-01,  2.50609346e-01,  3.89315037e-02]]),
#         array([[ 0.02928257,  0.0811081 ,  0.34265189, ...,  0.76027725,
#          0.04503105, -0.14042203],
#        [ 0.07748866,  0.00800484,  0.70524813, ..., -0.00543579,
# ...

# %%
FileExample['FAWeights_20201002']['Target'][0,0]['feature'].shape
# Out:
# (1, 4)

# %%
FileExample['FAWeights_20201002']['Target'][0,0]['feature'][0,0].shape
# Out:
# (1, 6)

# %%
FileExample['FAWeights_20201002']['Target'][0,0]['feature'][0,0][0,0].shape
# Out:
# (128, 10)

# %%
FileExample['FAWeights_20201002']['Target'][0,0]['feature'][0,0][0,0]
# Out:
# array([[-3.18361667e-02,  8.16413885e-02,  5.61596366e-04, ...,
#          1.07666604e-01, -5.57580583e-02, -3.30958069e-03],
#        [-3.80551569e-02, -6.69125169e-02,  3.00682178e-02, ...,
#          1.93439409e-01,  2.04475478e-01,  1.27680104e-03],
#        [ 1.66354482e-02,  1.17791780e-01,  1.33847519e-02, ...,
#          9.93874223e-02, -4.65868875e-02,  1.29808170e-01],
#        ...,
#        [-5.60920065e-02, -3.83856238e-02,  9.46275661e-02, ...,
#          1.01229037e-01,  3.69819120e-01,  1.53683716e-03],
#        [ 7.91577523e-01,  2.63401208e-02,  1.46566811e-01, ...,
#          3.09608614e-02,  6.96543551e-02, -3.43202241e-04],
#        [ 1.62829638e-01,  2.10279543e-02,  1.88090357e-02, ...,
#          1.47184835e-01,  2.50609346e-01,  3.89315037e-02]])
