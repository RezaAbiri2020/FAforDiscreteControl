# %% [markdown]
# # To perform multi-classifier SVM for reconstructed feature (HG) using FA in four targets. Check classification accuracy for the common space and private space

# %% [markdown]
# # Organzing and loading the data for all related days

# %%
# clean the memory 


# loading the library
import numpy as np
import os
import os.path
import scipy.io
from scipy.io import loadmat
import pickle
import hdf5storage as hdf5s
import h5py

# Experiment info 
# loading the imagined data

# initilize the values
class structtype():
    pass

ExptDays = list(['20201002','20201009','20201016','20201030','20201113','20201117','20201118','20201125','20201211'])
NumDay = len(ExptDays);
SessionDay = [ structtype() for i in range(NumDay)]
SessionDay[0].hhmmss = list(['145058','145910','150443','151528','152108'])
SessionDay[1].hhmmss = list(['134342','134836','135450','135947'])
SessionDay[2].hhmmss = list(['142924','144138','144924'])
SessionDay[3].hhmmss = list(['133902','134541','134838','141625','142426'])
SessionDay[4].hhmmss = list(['134350','135330','135938','140554'])
SessionDay[5].hhmmss = list(['111747','112508','113040','141009'])
SessionDay[6].hhmmss = list(['140255','140540'])
SessionDay[7].hhmmss = list(['105228','111217','112507','112711','113526','114108','143218','143824'])
SessionDay[8].hhmmss = list(['114458','114725'])

# for reading mat file from matlab
# it is easier to use class for further extracting necessary params or data
class MatFileAnalyzer():
    
    # first mandatory method; constructor
    def __init__(self,Mat_data):
        self.Fs = Mat_data['TrialData']['Params']['Fs'][0][0]
        self.UpdateRate = Mat_data['TrialData']['Params']['UpdateRate'][0][0]
        self.TargetID = Mat_data['TrialData']['TargetID'][0][0]
        self.SelectedTargetID = Mat_data['TrialData']['SelectedTargetID'][0][0]
        self.MaxReachTime = Mat_data['TrialData']['Params']['MaxReachTime'][0][0]
        self.Click_BinNum = Mat_data['TrialData']['Params']['ClickCounter'][0][0]
        
    def ECoG_Raw(self):
        
        Signals = Mat_data['TrialData']['BroadbandData']
        BinNum = Signals.shape[0]
        ECoGData = np.empty((0,128), dtype=float)
        for i in range(BinNum):
            Bin = Mat_data['TrialData']['BroadbandData'][i][0]
            BinName = h5py.h5r.get_name(Bin, Mat_data.id)
            BinInfo = Mat_data[BinName] 
            BinData = BinInfo[:,:]
            ECoGData = np.concatenate((ECoGData, BinData.T), axis=0)

        return ECoGData
    
    def Features_All(self):
        
        Features = Mat_data['TrialData']['NeuralFeatures']
        BinNum = Features.shape[0]
        NeuralFeatures = np.empty((0,896), dtype=float)
        
        if ExptDays[Day] == '20201002':
            
            for i in range(BinNum-int(self.Click_BinNum),BinNum,1):
                Bin = Mat_data['TrialData']['NeuralFeatures'][i][0]
                BinName = h5py.h5r.get_name(Bin, Mat_data.id)
                BinInfo = Mat_data[BinName] 
                BinData = BinInfo[:,:]
                NeuralFeatures = np.concatenate((NeuralFeatures, BinData), axis=0)
                
            return NeuralFeatures
        
        else:
                        
            BinControl = [] 
            for i in range(BinNum):
                if Mat_data['TrialData']['TaskState'][i][0] == 3:
                    BinControl.append(i)
             
            for j in BinControl[-int(TrialData.Click_BinNum):]:
                if ExptDays[Day] == '20201009':
                    j=j-1
                    
                Bin = Mat_data['TrialData']['NeuralFeatures'][j][0]
                BinName = h5py.h5r.get_name(Bin, Mat_data.id)
                BinInfo = Mat_data[BinName] 
                BinData = BinInfo[:,:]
                NeuralFeatures = np.concatenate((NeuralFeatures, BinData), axis=0)
                
            return NeuralFeatures
        
    def SmoothedFeatures_All(self):
        
        Features = Mat_data['TrialData']['SmoothedNeuralFeatures']
        BinNum = Features.shape[0]
        SmoothedNeuralFeatures = np.empty((0,896), dtype=float)
                  
        BinControl = [] 
        for i in range(BinNum):
            if Mat_data['TrialData']['TaskState'][i][0] == 3:
                BinControl.append(i)

        for j in BinControl[-int(TrialData.Click_BinNum):]:
            if ExptDays[Day] == '20201009':
                j=j-1

            Bin = Mat_data['TrialData']['SmoothedNeuralFeatures'][j][0]
            BinName = h5py.h5r.get_name(Bin, Mat_data.id)
            BinInfo = Mat_data[BinName] 
            BinData = BinInfo[:,:]
            SmoothedNeuralFeatures = np.concatenate((SmoothedNeuralFeatures, BinData), axis=0)

        return SmoothedNeuralFeatures   


Trials_T1 = np.empty((0,896), dtype=float)
Trials_T2 = np.empty((0,896), dtype=float)
Trials_T3 = np.empty((0,896), dtype=float)
Trials_T4 = np.empty((0,896), dtype=float)

# numnber of censequative bins for making correct selections
Click_BinNum_T1 = []
Click_BinNum_T2 = []
Click_BinNum_T3 = []
Click_BinNum_T4 = []

Day_NumTrial_T1 = []
Day_NumTrial_T2 = []
Day_NumTrial_T3 = []
Day_NumTrial_T4 = []


# loading the day/block/session data from the location
# day 0 does not have SmoothedNeuralFeatures
# day 6 the performance was not good
for Day in [ 1, 2, 3, 4, 5, 6, 7, 8]:
    ID1 = 0;
    ID2 = 0;
    ID3 = 0;
    ID4 = 0;

    for Se in range (len(SessionDay[Day].hhmmss)):

        print('Session:'+ SessionDay[Day].hhmmss[Se])
        # in windows
        if ExptDays[Day] in ['20201002','20201009']:
            DataPath =os.path.join('/media/reza/WindowsDrive/BRAVO1','CursorPlatform','Data',ExptDays[Day],'GangulyServer',ExptDays[Day],'RadialTask',SessionDay[Day].hhmmss[Se],'BCI_Fixed')
        
        else:
            DataPath =os.path.join('/media/reza/WindowsDrive/BRAVO1','CursorPlatform','Data',ExptDays[Day],'GangulyServer',ExptDays[Day],'DiscreteArrow',SessionDay[Day].hhmmss[Se],'BCI_Fixed')
        
        datadir = os.listdir(DataPath)

        # loading the trials
        for k in range(len(datadir)):

            print('Trial:',k+1)
            Mat_data = h5py.File(DataPath+'/'+datadir[k])
            TrialData = MatFileAnalyzer(Mat_data)
            ECoG1 = TrialData.ECoG_Raw()
            Fs = TrialData.Fs
            LenSignal = ECoG1.shape[0]
            MaxReachTime = TrialData.MaxReachTime

            # to find successful trials
            if ExptDays[Day] == '20201002' and ((LenSignal/Fs) < (MaxReachTime)):
                #print(True)
                NeuralFeatures = TrialData.Features_All()

                if TrialData.TargetID == 1:
                    ID1 = ID1+1                   
                    Trials_T1 = np.append(Trials_T1, NeuralFeatures, axis=0)

                elif TrialData.TargetID == 2:
                    ID2 = ID2+1
                    Trials_T2 = np.append(Trials_T2,NeuralFeatures, axis=0)

                elif TrialData.TargetID == 3:
                    ID3 = ID3+1
                    Trials_T3 = np.append(Trials_T3, NeuralFeatures, axis=0)

                elif TrialData.TargetID == 4:
                    ID4 = ID4+1
                    Trials_T4 = np.append(Trials_T4, NeuralFeatures, axis=0)

            elif ExptDays[Day] != '20201002' and TrialData.SelectedTargetID == TrialData.TargetID:
                #print(True)
                NeuralFeatures = TrialData.Features_All()
                SmoothedNeuralFeatures = TrialData.SmoothedFeatures_All()
                
                if TrialData.TargetID == 1:
                    ID1 = ID1+1                   
                    Trials_T1 = np.append(Trials_T1, SmoothedNeuralFeatures, axis=0)
                    Click_BinNum_T1.append(TrialData.Click_BinNum)

                elif TrialData.TargetID == 2:
                    ID2 = ID2+1
                    Trials_T2 = np.append(Trials_T2, SmoothedNeuralFeatures, axis=0)
                    Click_BinNum_T2.append(TrialData.Click_BinNum)

                elif TrialData.TargetID == 3:
                    ID3 = ID3+1
                    Trials_T3 = np.append(Trials_T3, SmoothedNeuralFeatures, axis=0)
                    Click_BinNum_T3.append(TrialData.Click_BinNum)

                elif TrialData.TargetID == 4:
                    ID4 = ID4+1
                    Trials_T4 = np.append(Trials_T4, SmoothedNeuralFeatures, axis=0)
                    Click_BinNum_T4.append(TrialData.Click_BinNum)
                    
    Day_NumTrial_T1.append(ID1)
    Day_NumTrial_T2.append(ID2)
    Day_NumTrial_T3.append(ID3)
    Day_NumTrial_T4.append(ID4)
    

print('End of Running Section')
# Out:
# Session:134342
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Session:134836
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Session:135450
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Session:135947
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Session:142924
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Session:144138
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Session:144924
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Session:133902
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Session:134541
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Session:134838
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Trial: 33
# Trial: 34
# Trial: 35
# Trial: 36
# Trial: 37
# Trial: 38
# Trial: 39
# Trial: 40
# Trial: 41
# Trial: 42
# Trial: 43
# Trial: 44
# Trial: 45
# Trial: 46
# Trial: 47
# Trial: 48
# Session:141625
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:142426
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:134350
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:135330
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:135938
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:140554
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:111747
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:112508
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:113040
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:141009
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:140255
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Session:140540
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:105228
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:111217
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:112507
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Session:112711
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Session:113526
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Session:114108
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Session:143218
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:143824
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Trial: 17
# Trial: 18
# Trial: 19
# Trial: 20
# Trial: 21
# Trial: 22
# Trial: 23
# Trial: 24
# Trial: 25
# Trial: 26
# Trial: 27
# Trial: 28
# Trial: 29
# Trial: 30
# Trial: 31
# Trial: 32
# Session:114458
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# Session:114725
# Trial: 1
# Trial: 2
# Trial: 3
# Trial: 4
# Trial: 5
# Trial: 6
# Trial: 7
# Trial: 8
# Trial: 9
# Trial: 10
# Trial: 11
# Trial: 12
# Trial: 13
# Trial: 14
# Trial: 15
# Trial: 16
# End of Running Section

# %%
Day_NumTrial_T1
# Out:
# [25, 21, 37, 31, 31, 10, 46, 9]

# %%
# plot one example of HG feature
import matplotlib.pyplot as plt
# %matplotlib inline
t_bin = np.arange(1,Trials_T4.shape[0]+1,1)
fig = plt.figure(figsize=(15,4))
ax = fig.add_axes([0,0,1,1])
ax.plot(t_bin,Trials_T4[:,800],'b')

# %% [markdown]
# # plot of ERP for engaged sequential bins per day and per target

# %%
#choose HG
Fe = 7
HG_T1 = Trials_T1[:,128*(Fe-1):128*Fe]
HG_T2 = Trials_T2[:,128*(Fe-1):128*Fe]
HG_T3 = Trials_T3[:,128*(Fe-1):128*Fe]
HG_T4 = Trials_T4[:,128*(Fe-1):128*Fe]

# for target 1
# initilize the values
class structtype():
    pass

SingleTrials_T1 = [ structtype() for i in range(len(Day_NumTrial_T1))]
ERP_T1 = [ structtype() for i in range(len(Day_NumTrial_T1))]

BinNum_ERP = int(max(Click_BinNum_T1))
for i in range(len(Day_NumTrial_T1)):
    # using 3D matrix for calculating ERP
    Temp = np.empty((BinNum_ERP,128,Day_NumTrial_T1[i]), dtype=float)
    Temp[:]=np.nan 

    for j in range(Day_NumTrial_T1[i]):
        if j == 0:
            Temp[0:int(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i]))+j]),:,j] = HG_T1[int(sum(Day_NumTrial_T1[0:i])):int(sum(Day_NumTrial_T1[0:i]))+int(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i]))+j]),:]
        else:
            Temp[0:int(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i]))+j-1]),:,j] = HG_T1[(int(sum(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i])):int(sum(Day_NumTrial_T1[0:i]))+(j-1)]))):(int(sum(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i])):int(sum(Day_NumTrial_T1[0:i]))+(j)]))),:]
            
    SingleTrials_T1[i].Day = Temp
    ERP_T1[i].Day = np.nanmean(Temp, axis=2)

# for target 2
# initilize the values
class structtype():
    pass

SingleTrials_T2 = [ structtype() for i in range(len(Day_NumTrial_T2))]
ERP_T2 = [ structtype() for i in range(len(Day_NumTrial_T2))]

BinNum_ERP = int(max(Click_BinNum_T2))
for i in range(len(Day_NumTrial_T2)):
    Temp = np.empty((BinNum_ERP,128,Day_NumTrial_T2[i]), dtype=float)
    Temp[:]=np.nan  

    for j in range(Day_NumTrial_T2[i]):
        if j == 0:
            Temp[0:int(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i]))+j]),:,j] = HG_T2[int(sum(Day_NumTrial_T2[0:i])):int(sum(Day_NumTrial_T2[0:i]))+int(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i]))+j]),:]
        else:
            Temp[0:int(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i]))+j-1]),:,j] = HG_T2[(int(sum(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i])):int(sum(Day_NumTrial_T2[0:i]))+(j-1)]))):(int(sum(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i])):int(sum(Day_NumTrial_T2[0:i]))+(j)]))),:]
            
    SingleTrials_T2[i].Day = Temp
    ERP_T2[i].Day = np.nanmean(Temp, axis=2)
    
# for target 3
# initilize the values
class structtype():
    pass

SingleTrials_T3 = [ structtype() for i in range(len(Day_NumTrial_T3))]
ERP_T3 = [ structtype() for i in range(len(Day_NumTrial_T3))]

BinNum_ERP = int(max(Click_BinNum_T3))
for i in range(len(Day_NumTrial_T3)):
    Temp = np.empty((BinNum_ERP,128,Day_NumTrial_T3[i]), dtype=float)
    Temp[:]=np.nan 

    for j in range(Day_NumTrial_T3[i]):
        if j == 0:
            Temp[0:int(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i]))+j]),:,j] = HG_T3[int(sum(Day_NumTrial_T3[0:i])):int(sum(Day_NumTrial_T3[0:i]))+int(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i]))+j]),:]
        else:
            Temp[0:int(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i]))+j-1]),:,j] = HG_T3[(int(sum(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i])):int(sum(Day_NumTrial_T3[0:i]))+(j-1)]))):(int(sum(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i])):int(sum(Day_NumTrial_T3[0:i]))+(j)]))),:]
            
    SingleTrials_T3[i].Day = Temp
    ERP_T3[i].Day = np.nanmean(Temp, axis=2)
    
# for target 4
# initilize the values
class structtype():
    pass

SingleTrials_T4 = [ structtype() for i in range(len(Day_NumTrial_T4))]
ERP_T4 = [ structtype() for i in range(len(Day_NumTrial_T4))]

BinNum_ERP = int(max(Click_BinNum_T4))
for i in range(len(Day_NumTrial_T4)):
    Temp = np.empty((BinNum_ERP,128,Day_NumTrial_T4[i]), dtype=float)
    Temp[:]=np.nan 

    for j in range(Day_NumTrial_T4[i]):
        if j == 0:
            Temp[0:int(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i]))+j]),:,j] = HG_T4[int(sum(Day_NumTrial_T4[0:i])):int(sum(Day_NumTrial_T4[0:i]))+int(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i]))+j]),:]
        else:
            Temp[0:int(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i]))+j-1]),:,j] = HG_T4[(int(sum(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i])):int(sum(Day_NumTrial_T4[0:i]))+(j-1)]))):(int(sum(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i])):int(sum(Day_NumTrial_T4[0:i]))+(j)]))),:]
            
    SingleTrials_T4[i].Day = Temp
    ERP_T4[i].Day = np.nanmean(Temp, axis=2)
# Out:
# <ipython-input-174-3f642881761f>:29: RuntimeWarning: Mean of empty slice
#   ERP_T1[i].Day = np.nanmean(Temp, axis=2)
# <ipython-input-174-3f642881761f>:51: RuntimeWarning: Mean of empty slice
#   ERP_T2[i].Day = np.nanmean(Temp, axis=2)
# <ipython-input-174-3f642881761f>:73: RuntimeWarning: Mean of empty slice
#   ERP_T3[i].Day = np.nanmean(Temp, axis=2)
# <ipython-input-174-3f642881761f>:95: RuntimeWarning: Mean of empty slice
#   ERP_T4[i].Day = np.nanmean(Temp, axis=2)

# %%
# plot the ERP for a chosen channel 

# %matplotlib inline

ListMarker = ['blue','red','orange','green']
ch = 100

fig, axes = plt.subplots(4,8,figsize=(15,15))
fig.suptitle('HG feature values; ERP for Channel:'+str(ch), fontsize=20)

ERP_All = [ERP_T1, ERP_T2, ERP_T3, ERP_T4]

for target in range(4):
    ERP_AllDay = ERP_All[target]
    
    for ax in range(8):
        ERP_plot = ERP_AllDay[ax].Day
        t_bin = np.arange(1,ERP_plot.shape[0]+1,1)
        if target == 0 and ax == 0:
            axes[target, ax].plot(t_bin,ERP_plot[:,ch],color=ListMarker[target])
            axes[target, ax].set_title('T:'+str(target+1)+'  D:'+str(ax+1),fontsize=16)
            axes[target, ax].set_xlabel('Bin #',fontsize=12)
            axes[target, ax].set_ylabel('HG Feature',fontsize=12)
            axes[target, ax].set_ylim([-2,0])
            
        else:
            axes[target, ax].plot(t_bin,ERP_plot[:,ch],color=ListMarker[target])
            axes[target, ax].set_title('T:'+str(target+1)+'  D: '+str(ax+1),fontsize=16)
            axes[target, ax].set_ylim([-2,0])
            
plt.tight_layout()
plt.savefig('ERP_Bins_hg_8Days_Ch100.png',facecolor='w', transparent=False, dpi=300)

# %% [markdown]
# # Selecting the feature and input values for FA analysis

# %%
# choose this option
Case = 1 
# 1: is pure feature of HG and concatanated of all trials and targets; 
# 2: is a single value of HG per trial then concatanated of all trials and targets;  

if Case == 1:
    HG_Cat = np.concatenate((HG_T1, HG_T2, HG_T3, HG_T4), axis=0)
    HG_CatTarget_Mean = np.nanmean(HG_Cat, axis=0)
    HG_CatTarget = HG_Cat-HG_CatTarget_Mean
    
elif Case == 2:
    
    PointTrials_T1 = np.empty((0,128), dtype=float)
    for i in range(6):
        Temp1 = SingleTrials_T1[i].Day 
        Temp2 = np.nanmean(Temp1, axis=0)
        PointTrials_T1 = np.append(PointTrials_T1, Temp2.T, axis=0)

    PointTrials_T2 = np.empty((0,128), dtype=float)
    for i in range(6):
        Temp1 = SingleTrials_T2[i].Day 
        Temp2 = np.nanmean(Temp1, axis=0)
        PointTrials_T2 = np.append(PointTrials_T2, Temp2.T, axis=0)

    PointTrials_T3 = np.empty((0,128), dtype=float)
    for i in range(6):
        Temp1 = SingleTrials_T3[i].Day 
        Temp2 = np.nanmean(Temp1, axis=0)
        PointTrials_T3 = np.append(PointTrials_T3, Temp2.T, axis=0)

    PointTrials_T4 = np.empty((0,128), dtype=float)
    for i in range(6):
        Temp1 = SingleTrials_T4[i].Day 
        Temp2 = np.nanmean(Temp1, axis=0)
        PointTrials_T4 = np.append(PointTrials_T4, Temp2.T, axis=0)
    
    HG_Cat = np.concatenate((PointTrials_T1, PointTrials_T2, PointTrials_T3, PointTrials_T4), axis=0)
    HG_CatTarget_Mean = np.nanmean(HG_Cat, axis=0)
    HG_CatTarget = HG_Cat-HG_CatTarget_Mean      


HG_Cat.shape
# Out:
# (3785, 128)

# %%
HG_Cat.shape
# Out:
# (2750, 128)

# %% [markdown]
# # preliminary design/ anlaysis for FA

# %%
from sklearn.decomposition import FactorAnalysis
from factor_analyzer import FactorAnalyzer
import pandas as pd
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer.factor_analyzer import calculate_kmo

# check the “factorability” of our dataset

#artlett’s test: the p_value should be statistically significant
chi_square_value,p_value=calculate_bartlett_sphericity(HG_CatTarget)
print('pvalue:'+str(p_value))

# Kaiser-Meyer-Olkin (KMO) Test: Value of KMO less than 0.6 is considered inadequate. should be more than 0.6
kmo_all,kmo_model=calculate_kmo(HG_CatTarget)
print('kmo_model:'+str(kmo_model))

# calcuate the number of necessary factors
fa = FactorAnalyzer(128,rotation=None)
fa.fit(HG_CatTarget)

# Check Eigenvalues; the number of bigger than 1 is good; here 14
ev, v = fa.get_eigenvalues()
print (ev)

# Create scree plot using matplotlib
fig = plt.figure(figsize=(12,4))
ax = fig.add_axes([0,0,1,1])
ax.scatter(range(1,HG_CatTarget.shape[1]+1),ev)
ax.plot(range(1,HG_CatTarget.shape[1]+1),ev)
ax.plot(range(1,HG_CatTarget.shape[1]+1),[1]*128,'-')
ax.set_title('Scree Plot')
ax.set_xlabel('Factors')
ax.set_ylabel('Eigenvalue')
ax.grid()
# Out:
# pvalue:0.0
# kmo_model:0.9900073632286834
# /home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/factor_analyzer/utils.py:248: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn('The inverse of the variance-covariance matrix '
# [5.91493022e+01 1.07390462e+01 6.93364158e+00 4.00951489e+00
#  2.93964317e+00 2.68593422e+00 2.09600240e+00 1.64737851e+00
#  1.44879628e+00 1.28355861e+00 1.14400648e+00 1.01860824e+00
#  9.32789569e-01 8.87626225e-01 7.83945703e-01 7.71823022e-01
#  7.24188192e-01 6.72603389e-01 6.45261530e-01 6.16864404e-01
#  5.90983602e-01 5.82319534e-01 5.74943425e-01 5.47487204e-01
#  5.28732963e-01 5.23448986e-01 4.99360042e-01 4.96245340e-01
#  4.81872150e-01 4.73528610e-01 4.66681952e-01 4.59090866e-01
#  4.46527064e-01 4.40181889e-01 4.31788685e-01 4.28711877e-01
#  4.24255467e-01 4.10771624e-01 4.07254358e-01 4.00812051e-01
#  3.93746892e-01 3.88244892e-01 3.75261983e-01 3.69571457e-01
#  3.66797169e-01 3.62150546e-01 3.55961552e-01 3.49432411e-01
#  3.47483208e-01 3.45394622e-01 3.39714683e-01 3.34619595e-01
#  3.32320232e-01 3.26780308e-01 3.14312570e-01 3.12999489e-01
#  3.06924463e-01 3.03877067e-01 3.00766636e-01 2.96833906e-01
#  2.91295493e-01 2.87195068e-01 2.78841349e-01 2.78559387e-01
#  2.73033779e-01 2.68351942e-01 2.59417737e-01 2.58196720e-01
#  2.50958886e-01 2.40305040e-01 2.39338137e-01 2.34823346e-01
#  2.32169236e-01 2.27060757e-01 2.18681617e-01 2.13345996e-01
#  2.09397728e-01 2.07578168e-01 2.00570964e-01 1.94909623e-01
#  1.89821102e-01 1.87848962e-01 1.83746394e-01 1.81332493e-01
#  1.76156941e-01 1.74014810e-01 1.72568139e-01 1.67123267e-01
#  1.63073971e-01 1.60547798e-01 1.58363261e-01 1.57580584e-01
#  1.51390226e-01 1.46642927e-01 1.41381084e-01 1.39607707e-01
#  1.35340763e-01 1.32326186e-01 1.31382408e-01 1.27879861e-01
#  1.26684483e-01 1.22083439e-01 1.19648672e-01 1.14713681e-01
#  1.13162769e-01 1.11649936e-01 1.06384714e-01 1.04776513e-01
#  1.02381604e-01 9.90269176e-02 9.58022168e-02 9.30152267e-02
#  9.04080655e-02 8.76929065e-02 8.40671151e-02 8.07028948e-02
#  7.89362596e-02 7.64681979e-02 7.32125329e-02 6.99054999e-02
#  6.78087643e-02 6.69514809e-02 6.38645446e-02 5.77109920e-02
#  5.56723677e-02 4.72593810e-02 4.19686294e-02 3.71541143e-02]

# %% [markdown]
# # Factor Analysis for concatanated single-trials for all targets

# %%
from sklearn.decomposition import FactorAnalysis
from factor_analyzer import FactorAnalyzer
import pandas as pd

# initilize the values
class structtype():
    pass
# for FA signals
FASignal = [ structtype() for i in range(4)]

fa = FactorAnalyzer(10,rotation=None)
fa.fit(HG_CatTarget)
FAWeight = fa.loadings_
if Case ==1:
    FASignal[0].Target = (HG_T1-HG_CatTarget_Mean)@ (FAWeight)
    FASignal[1].Target = (HG_T2-HG_CatTarget_Mean)@ (FAWeight)
    FASignal[2].Target = (HG_T3-HG_CatTarget_Mean)@ (FAWeight)
    FASignal[3].Target = (HG_T4-HG_CatTarget_Mean)@ (FAWeight)
    
elif Case ==2:
    FASignal[0].Target = (PointTrials_T1)@ (FAWeight)
    FASignal[1].Target = (PointTrials_T2)@ (FAWeight)
    FASignal[2].Target = (PointTrials_T3)@ (FAWeight)
    FASignal[3].Target = (PointTrials_T4)@ (FAWeight)

        
# Get variance of each factors
fa.get_factor_variance()
# first row: SS Loadings
# second row: Proportion Var per factor
# third row: Cumulative Var up to that factor
# Out:
# (array([58.87405829, 10.54573492,  6.58242043,  3.74354555,  2.66051285,
#          2.32661032,  1.79014882,  1.28792909,  1.14797889,  0.97252563]),
#  array([0.45995358, 0.08238855, 0.05142516, 0.02924645, 0.02078526,
#         0.01817664, 0.01398554, 0.01006195, 0.00896859, 0.00759786]),
#  array([0.45995358, 0.54234213, 0.59376729, 0.62301374, 0.643799  ,
#         0.66197564, 0.67596118, 0.68602313, 0.69499171, 0.70258957]))

# %%
Activation_Signal = FASignal[0].Target
Activation_Signal.shape
# Out:
# (975, 10)

# %%
# test the factors
# %matplotlib inline
Activation_Signal =FASignal[0].Target
t_bin = np.arange(1,Activation_Signal.shape[0]+1,1)
fig = plt.figure(figsize=(15,4))
ax = fig.add_axes([0,0,1,1])
ax.plot(t_bin,Activation_Signal[:,0],'b')
#ax.set_xlim([0,1])
#ax.set_ylim([0,2])

# %%
# plot for the grant

# plot one example of HG feature for a specific target
channel = 100
import matplotlib.pyplot as plt
# %matplotlib inline
t_bin = np.arange(1,HG_T1.shape[0]+1,1)
fig = plt.figure(figsize=(15,4))
ax = fig.add_axes([0,0,1,1])
ax.plot(t_bin,HG_T1[:,channel],'b')

# the related factor signal
Activation_Signal =FASignal[0].Target
ax.plot(t_bin,Activation_Signal[:,3],'r')

# %%
# 3D plot for the first 3 FA signals; choose the options 
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import matplotlib.animation as animation

# %matplotlib auto 

# %matplotlib qt
# %matplotlib notebook

matplotlib.rcParams.update({'font.size': 18})

ax = plt.axes(projection='3d')
ax.set_xlabel('Dim1')
ax.set_ylabel('Dim2')
ax.set_zlabel('Dim3')
#ax.set_xlim([0,15])
#ax.set_ylim([-5,5])
#ax.set_zlim([-5,5])

ListMarker = ['blue','red','orange','green']
ListLegend = ['Target1','Target2','Target3','target4']

for target in range(4):
    # Data for a three-dimensional line
    Activation_Signal = FASignal[target].Target
    xline = Activation_Signal[:,0]
    yline = Activation_Signal[:,1]
    zline = Activation_Signal[:,2]
    ax.plot3D(xline, yline, zline,color=ListMarker[target], label=ListLegend[target])
    
plt.show()
ax.legend(loc=0,fontsize=20)

# for only rotation
"""
# rotate the axes and update
for angle in range(0, 360):
    ax.view_init(30, angle)
    plt.draw()
    plt.pause(.001)
"""
# Out:
# Using matplotlib backend: TkAgg
# Warning: Cannot change to a different GUI toolkit: qt. Using tk instead.
# Warning: Cannot change to a different GUI toolkit: notebook. Using tk instead.
# '\n# rotate the axes and update\nfor angle in range(0, 360):\n    ax.view_init(30, angle)\n    plt.draw()\n    plt.pause(.001)\n'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 804, in callit
#     func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/_backend_tk.py", line 253, in idle_draw
#     self.draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x7f8d75a7f550>
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/_backend_tk.py", line 242, in resize
#     self.draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x7f8d75a7f550>
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 804, in callit
#     func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/_backend_tk.py", line 253, in idle_draw
#     self.draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x7f8d75a7f550>

# %%
# creating a fig of 3D plot for the first 3 FA signals; choose the options 
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib auto 

# %matplotlib qt
# %matplotlib notebook

matplotlib.rcParams.update({'font.size': 18})

# Create a figure and a 3D Axes
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('Dim1')
ax.set_ylabel('Dim2')
ax.set_zlabel('Dim3')
#ax.set_xlim([0,15])
#ax.set_ylim([-5,5])
#ax.set_zlim([-5,5])

ListMarker = ['blue','red','orange','green']
ListLegend = ['Target1','Target2','Target3','target4']

def init():
    for target in range(4):
        # Data for a three-dimensional line
        Activation_Signal = FASignal[target].Target
        xline = Activation_Signal[:,0]
        yline = Activation_Signal[:,1]
        zline = Activation_Signal[:,2]
        ax.plot3D(xline, yline, zline,color=ListMarker[target], label=ListLegend[target])
    
    plt.show()
    ax.legend(loc='upper right',fontsize=10)

    return fig,

def animate(i):
    ax.view_init(elev=10., azim=i)
    return fig,

# Animate
#anim = animation.FuncAnimation(fig, animate, init_func=init, frames=360, interval=20, blit=True)
# Save
#anim.save('rotation.gif', dpi=80, writer='imagemagick')
#anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])
# Out:
# Using matplotlib backend: TkAgg
# Warning: Cannot change to a different GUI toolkit: qt. Using tk instead.
# Warning: Cannot change to a different GUI toolkit: notebook. Using tk instead.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 804, in callit
#     func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/_backend_tk.py", line 253, in idle_draw
#     self.draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x7f8d8c0473d0>
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/_backend_tk.py", line 242, in resize
#     self.draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x7f8d8c0473d0>
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/tkinter/__init__.py", line 804, in callit
#     func(*args)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/_backend_tk.py", line 253, in idle_draw
#     self.draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "/home/reza/anaconda3/envs/FAforDiscreteControl/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 1544, in _draw
#     def _draw(renderer): raise Done(renderer)
# matplotlib.backend_bases._get_renderer.<locals>.Done: <matplotlib.backends.backend_agg.RendererAgg object at 0x7f8d8c0473d0>

# %% [markdown]
# # Plot all latent factors for all targets across bins and days

# %%
# %matplotlib inline
# for plotting purpose
if Case == 1:
    Min_BinNum =min([Trials_T1.shape[0], Trials_T2.shape[0], Trials_T3.shape[0], Trials_T4.shape[0]])

elif Case == 2:
    Min_BinNum =min([PointTrials_T1.shape[0], PointTrials_T2.shape[0], PointTrials_T3.shape[0], PointTrials_T4.shape[0]])

ListMarker = ['blue','red','orange','green']
ListLegend = ['Target1','Target2','Target3','target4']

fig, axes = plt.subplots(10,1,figsize=(15,15))
fig.suptitle('Projected Single Trials', fontsize=20)

for target in range(4):
    Activation_Signal = FASignal[target].Target
    t_bin = np.arange(1,Min_BinNum,1)
    
    for ax in range(axes.shape[0]):
        if ax == 0:
            axes[ax].plot(t_bin,Activation_Signal[1:Min_BinNum,ax],color=ListMarker[target], label=ListLegend[target])
            axes[ax].set_title('Dim: '+str(ax+1),fontsize=16)
            axes[ax].set_xlabel('Bin #',fontsize=12)
            axes[ax].set_ylabel('HG Feature',fontsize=12)
            
        else:
            axes[ax].plot(t_bin,Activation_Signal[1:Min_BinNum,ax],color=ListMarker[target])
            axes[ax].set_title('Dim: '+str(ax+1),fontsize=16)
                
            
axes[0].legend(loc=1)
plt.tight_layout()
#plt.savefig('FA_hg_Points_6Days.png',dpi=300)

# %% [markdown]
# # plot of ERP for engaged sequential bins of FA per day and per target

# %%
# the inputs will be FA signals

HGFA_T1 = FASignal[0].Target
HGFA_T2 = FASignal[1].Target
HGFA_T3 = FASignal[2].Target
HGFA_T4 = FASignal[3].Target


# for target 1
# initilize the values
class structtype():
    pass

SingleTrials_T1 = [ structtype() for i in range(len(Day_NumTrial_T1))]
ERPFA_T1 = [ structtype() for i in range(len(Day_NumTrial_T1))]

BinNum_ERP = int(max(Click_BinNum_T1))
for i in range(len(Day_NumTrial_T1)):
    Temp = np.empty((BinNum_ERP,10,Day_NumTrial_T1[i]), dtype=float)
    Temp[:]=np.nan 

    for j in range(Day_NumTrial_T1[i]):
        if j == 0:
            Temp[0:int(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i]))+j]),:,j] = HGFA_T1[int(sum(Day_NumTrial_T1[0:i])):int(sum(Day_NumTrial_T1[0:i]))+int(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i]))+j]),:]
        else:
            Temp[0:int(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i]))+j-1]),:,j] = HGFA_T1[(int(sum(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i])):int(sum(Day_NumTrial_T1[0:i]))+(j-1)]))):(int(sum(Click_BinNum_T1[int(sum(Day_NumTrial_T1[0:i])):int(sum(Day_NumTrial_T1[0:i]))+(j)]))),:]
            
    SingleTrials_T1[i].Day = Temp
    ERPFA_T1[i].Day = np.nanmean(Temp, axis=2)

# for target 2
# initilize the values
class structtype():
    pass

SingleTrials_T2 = [ structtype() for i in range(len(Day_NumTrial_T2))]
ERPFA_T2 = [ structtype() for i in range(len(Day_NumTrial_T2))]

BinNum_ERP = int(max(Click_BinNum_T2))
for i in range(len(Day_NumTrial_T2)):
    Temp = np.empty((BinNum_ERP,10,Day_NumTrial_T2[i]), dtype=float)
    Temp[:]=np.nan  

    for j in range(Day_NumTrial_T2[i]):
        if j == 0:
            Temp[0:int(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i]))+j]),:,j] = HGFA_T2[int(sum(Day_NumTrial_T2[0:i])):int(sum(Day_NumTrial_T2[0:i]))+int(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i]))+j]),:]
        else:
            Temp[0:int(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i]))+j-1]),:,j] = HGFA_T2[(int(sum(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i])):int(sum(Day_NumTrial_T2[0:i]))+(j-1)]))):(int(sum(Click_BinNum_T2[int(sum(Day_NumTrial_T2[0:i])):int(sum(Day_NumTrial_T2[0:i]))+(j)]))),:]
           
    SingleTrials_T2[i].Day = Temp
    ERPFA_T2[i].Day = np.nanmean(Temp, axis=2)
    
# for target 3
# initilize the values
class structtype():
    pass

SingleTrials_T3 = [ structtype() for i in range(len(Day_NumTrial_T3))]
ERPFA_T3 = [ structtype() for i in range(len(Day_NumTrial_T3))]

BinNum_ERP = int(max(Click_BinNum_T3))
for i in range(len(Day_NumTrial_T3)):
    Temp = np.empty((BinNum_ERP,10,Day_NumTrial_T3[i]), dtype=float)
    Temp[:]=np.nan 

    for j in range(Day_NumTrial_T3[i]):
        if j == 0:
            Temp[0:int(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i]))+j]),:,j] = HGFA_T3[int(sum(Day_NumTrial_T3[0:i])):int(sum(Day_NumTrial_T3[0:i]))+int(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i]))+j]),:]
        else:
            Temp[0:int(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i]))+j-1]),:,j] = HGFA_T3[(int(sum(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i])):int(sum(Day_NumTrial_T3[0:i]))+(j-1)]))):(int(sum(Click_BinNum_T3[int(sum(Day_NumTrial_T3[0:i])):int(sum(Day_NumTrial_T3[0:i]))+(j)]))),:]
            
    SingleTrials_T3[i].Day = Temp
    ERPFA_T3[i].Day = np.nanmean(Temp, axis=2)
    
# for target 4
# initilize the values
class structtype():
    pass

SingleTrials_T4 = [ structtype() for i in range(len(Day_NumTrial_T4))]
ERPFA_T4 = [ structtype() for i in range(len(Day_NumTrial_T4))]

BinNum_ERP = int(max(Click_BinNum_T4))
for i in range(len(Day_NumTrial_T4)):
    Temp = np.empty((BinNum_ERP,10,Day_NumTrial_T4[i]), dtype=float)
    Temp[:]=np.nan 

    for j in range(Day_NumTrial_T4[i]):
        if j == 0:
            Temp[0:int(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i]))+j]),:,j] = HGFA_T4[int(sum(Day_NumTrial_T4[0:i])):int(sum(Day_NumTrial_T4[0:i]))+int(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i]))+j]),:]
        else:
            Temp[0:int(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i]))+j-1]),:,j] = HGFA_T4[(int(sum(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i])):int(sum(Day_NumTrial_T4[0:i]))+(j-1)]))):(int(sum(Click_BinNum_T4[int(sum(Day_NumTrial_T4[0:i])):int(sum(Day_NumTrial_T4[0:i]))+(j)]))),:]
            
    SingleTrials_T4[i].Day = Temp
    ERPFA_T4[i].Day = np.nanmean(Temp, axis=2)
    

# plot the ERP for a chosen Dim

# %matplotlib inline

ListMarker = ['blue','red','orange','green']
Dim = 1

fig, axes = plt.subplots(4,8,figsize=(15,15))
fig.suptitle('FA of HG feature values; ERP for Dim:'+str(Dim), fontsize=20)

ERPFA_All = [ERPFA_T1, ERPFA_T2, ERPFA_T3, ERPFA_T4]

for target in range(4):
    ERPFA_AllDay = ERPFA_All[target]
    
    for ax in range(8):
        ERP_plot = ERPFA_AllDay[ax].Day
        t_bin = np.arange(1,ERP_plot.shape[0]+1,1)
        if target == 0 and ax == 0:
            axes[target, ax].plot(t_bin,ERP_plot[:,Dim],color=ListMarker[target])
            axes[target, ax].set_title('T:'+str(target+1)+'  D:'+str(ax+1),fontsize=16)
            axes[target, ax].set_xlabel('Bin #',fontsize=12)
            axes[target, ax].set_ylabel('FA of HG Feature',fontsize=12)
            axes[target, ax].set_ylim([-4,23])
            
        else:
            axes[target, ax].plot(t_bin,ERP_plot[:,Dim],color=ListMarker[target])
            axes[target, ax].set_title('T:'+str(target+1)+'  D: '+str(ax+1),fontsize=16)
            axes[target, ax].set_ylim([-4,23])
            
plt.tight_layout()
#plt.savefig('ERP_Bins_hgFA_DeMean_8Days_Dim1.png',facecolor='w', transparent=False, dpi=300)
# Out:
# <ipython-input-242-a2142f91d039>:29: RuntimeWarning: Mean of empty slice
#   ERPFA_T1[i].Day = np.nanmean(Temp, axis=2)
# <ipython-input-242-a2142f91d039>:51: RuntimeWarning: Mean of empty slice
#   ERPFA_T2[i].Day = np.nanmean(Temp, axis=2)
# <ipython-input-242-a2142f91d039>:73: RuntimeWarning: Mean of empty slice
#   ERPFA_T3[i].Day = np.nanmean(Temp, axis=2)
# <ipython-input-242-a2142f91d039>:95: RuntimeWarning: Mean of empty slice
#   ERPFA_T4[i].Day = np.nanmean(Temp, axis=2)

# %%
# plot for grant
# plot the ERP for a chosen channel 

# %matplotlib inline

ListMarker = ['blue','red']
# choose the channel and target and dim
ch = 50#100
target = 0
dim = 4

fig, axes = plt.subplots(2,8,figsize=(18,5))
fig.suptitle('High Gamma Power Across 8 Days. Top row: avereged values for a channel. Bottom row: avereged values for a latent factor', fontsize=20)

ERP_All = [ERP_T1, ERP_T2, ERP_T3, ERP_T4]
ERPFA_All = [ERPFA_T1, ERPFA_T2, ERPFA_T3, ERPFA_T4]

for row in range(2):
    if row == 0:
        ERP_AllDay = ERP_All[target]
    else:
        ERPFA_AllDay = ERPFA_All[target]
    
    for ax in range(8):
        if row == 0:
            ERP_plot = ERP_AllDay[ax].Day
            colum = ch
        else:
            ERP_plot = ERPFA_AllDay[ax].Day
            colum = dim
                
        t_bin = np.arange(1,ERP_plot.shape[0]+1,1)
        axes[row, ax].plot(t_bin,ERP_plot[:,colum],color=ListMarker[row])
        axes[row, ax].set_title('D:'+str(ax+1),fontsize=16)
        if ax == 0:
            axes[row, ax].set_xlabel('Sample Point',fontsize=12)
            axes[row, ax].set_ylabel('High Gamma Power',fontsize=12)
        
        if row == 0:
            #pass
            axes[row, ax].set_ylim([-0.3,1])
        else:
            pass
            #axes[row, ax].set_ylim([10,24])

            
plt.tight_layout()
#plt.savefig('ERP_Bins_hg_8Days_Ch100.png',facecolor='w', transparent=False, dpi=300)

# %% [markdown]
# # Selecting the input for SVM analysis

# %%
# Run the linear SVM for these inputs

# first chose: only HG values without any de-mean and FA; 128 dimensions
# second chose: Latent factors of de-mean HG; 10 factors; 10 dimensions
# third chose: calculate the reconstructed de-noised HG; 128 dimensions
# forth chose: calculate the residual value/ private variance out of FA; 128 dimensions  

CaseSVM = 4


if CaseSVM == 1:
    X_T1 = HG_T1
    X_T2 = HG_T2
    X_T3 = HG_T3
    X_T4 = HG_T4
    
elif CaseSVM == 2:
    X_T1 = FASignal[0].Target
    X_T2 = FASignal[1].Target
    X_T3 = FASignal[2].Target
    X_T4 = FASignal[3].Target

elif CaseSVM == 3:
    X_T1 = (FASignal[0].Target) @ (FAWeight.T)
    X_T2 = (FASignal[1].Target) @ (FAWeight.T)
    X_T3 = (FASignal[2].Target) @ (FAWeight.T)
    X_T4 = (FASignal[3].Target) @ (FAWeight.T)
    
elif CaseSVM == 4: 
    X_Rec_T1 = (FASignal[0].Target) @ (FAWeight.T)
    X_Rec_T2 = (FASignal[1].Target) @ (FAWeight.T)
    X_Rec_T3 = (FASignal[2].Target) @ (FAWeight.T)
    X_Rec_T4 = (FASignal[3].Target) @ (FAWeight.T)
    
    X_T1 = HG_T1-X_Rec_T1
    X_T2 = HG_T2-X_Rec_T2
    X_T3 = HG_T3-X_Rec_T3
    X_T4 = HG_T4-X_Rec_T4

# %%
X_T3.shape
# Out:
# (914, 128)

# %% [markdown]
# # Performing multi-classifier SVM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


# balance the data
Indx = min(X_T1.shape[0], X_T2.shape[0],X_T3.shape[0],X_T4.shape[0])
step = 1
KeepSample = 50 

X_heldout_T1 = X_T1[(Indx-KeepSample):Indx:step,:]
X_heldout_T2 = X_T2[(Indx-KeepSample):Indx:step,:]
X_heldout_T3 = X_T3[(Indx-KeepSample):Indx:step,:]
X_heldout_T4 = X_T4[(Indx-KeepSample):Indx:step,:]


y_heldout_T1 = np.zeros((X_heldout_T1.shape[0],1))
y_heldout_T2 = np.ones((X_heldout_T2.shape[0],1))
y_heldout_T3 = 2*np.ones((X_heldout_T3.shape[0],1))
y_heldout_T4 = 3*np.ones((X_heldout_T4.shape[0],1))


X_heldout = np.concatenate((X_heldout_T1, X_heldout_T2, X_heldout_T3, X_heldout_T4), axis=0) 
y_heldout = np.concatenate((y_heldout_T1, y_heldout_T2, y_heldout_T3, y_heldout_T4), axis=0)
# flatten the array
y_heldout =y_heldout.ravel()

X_T1 = X_T1[0:(Indx-KeepSample):step,:]
X_T2 = X_T2[0:(Indx-KeepSample):step,:]
X_T3 = X_T3[0:(Indx-KeepSample):step,:]
X_T4 = X_T4[0:(Indx-KeepSample):step,:]

y_T1 = np.zeros((X_T1.shape[0],1))
y_T2 = np.ones((X_T2.shape[0],1))
y_T3 = 2*np.ones((X_T3.shape[0],1))
y_T4 = 3*np.ones((X_T4.shape[0],1))

X = np.concatenate((X_T1, X_T2, X_T3, X_T4), axis=0) 
y = np.concatenate((y_T1, y_T2, y_T3, y_T4), axis=0)
# flatten the array
y =y.ravel()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (2280, 128)

# %%
from sklearn.svm import SVC
model_multi = SVC(C=1, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', break_ties=False, random_state=None)
model_multi.fit(X_train,y_train)
SVC()
# Out:
# SVC()

# %%
# get support vectors; should be less than the training pointss
NumSV = model_multi.support_vectors_
NumSV.shape
# Out:
# (546, 128)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# testing the trainig result
predictions_multi = model_multi.predict(X_test)
print(confusion_matrix(y_test, predictions_multi))
print('\n')
print(classification_report(y_test, predictions_multi))
# Out:
# [[283   0  19   0]
#  [  2 247  10  10]
#  [  7  11 229  10]
#  [  1  26   8 261]]
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95       302
#          1.0       0.87      0.92      0.89       269
#          2.0       0.86      0.89      0.88       257
#          3.0       0.93      0.88      0.90       296
#
#     accuracy                           0.91      1124
#    macro avg       0.91      0.91      0.91      1124
# weighted avg       0.91      0.91      0.91      1124

# %%
# testing the held_out data
predictions_heldout_multi = model_multi.predict(X_heldout)
print(confusion_matrix(y_heldout, predictions_heldout_multi))
print('\n')
print(classification_report(y_heldout, predictions_heldout_multi))
# Out:
# [[39  0 11  0]
#  [ 0 48  2  0]
#  [ 0  2 48  0]
#  [ 0 17  0 33]]
#
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.78      0.88        50
#          1.0       0.72      0.96      0.82        50
#          2.0       0.79      0.96      0.86        50
#          3.0       1.00      0.66      0.80        50
#
#     accuracy                           0.84       200
#    macro avg       0.88      0.84      0.84       200
# weighted avg       0.88      0.84      0.84       200

# %% [markdown]
# # Parameter adjustment for multi-classifier SVM

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C':[0.1, 1, 10, 100, 1000], 'gamma':[1, 0.1, 0.01, 0.001, 0.0001]}
grid_multi = GridSearchCV(model_multi,param_grid, verbose=3)
grid_multi.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.939, total=   0.1s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] ...................... C=0.1, gamma=1, score=0.945, total=   0.1s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.908, total=   0.1s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV] ...................... C=0.1, gamma=1, score=0.928, total=   0.1s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.917, total=   0.1s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.939, total=   0.1s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.945, total=   0.1s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.908, total=   0.1s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.928, total=   0.1s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.917, total=   0.1s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................... C=0.1, gamma=0.01, score=0.939, total=   0.1s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................... C=0.1, gamma=0.01, score=0.945, total=   0.1s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................... C=0.1, gamma=0.01, score=0.908, total=   0.1s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................... C=0.1, gamma=0.01, score=0.928, total=   0.1s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................... C=0.1, gamma=0.01, score=0.917, total=   0.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................. C=0.1, gamma=0.001, score=0.939, total=   0.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................. C=0.1, gamma=0.001, score=0.945, total=   0.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................. C=0.1, gamma=0.001, score=0.908, total=   0.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................. C=0.1, gamma=0.001, score=0.928, total=   0.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .................. C=0.1, gamma=0.001, score=0.917, total=   0.1s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] ................. C=0.1, gamma=0.0001, score=0.939, total=   0.1s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] ................. C=0.1, gamma=0.0001, score=0.945, total=   0.1s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] ................. C=0.1, gamma=0.0001, score=0.908, total=   0.1s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] ................. C=0.1, gamma=0.0001, score=0.928, total=   0.1s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] ................. C=0.1, gamma=0.0001, score=0.917, total=   0.1s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................ C=1, gamma=1, score=0.912, total=   0.1s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................ C=1, gamma=1, score=0.936, total=   0.1s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................ C=1, gamma=1, score=0.897, total=   0.1s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................ C=1, gamma=1, score=0.910, total=   0.1s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................ C=1, gamma=1, score=0.882, total=   0.1s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ...................... C=1, gamma=0.1, score=0.912, total=   0.1s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ...................... C=1, gamma=0.1, score=0.936, total=   0.2s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ...................... C=1, gamma=0.1, score=0.897, total=   0.1s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ...................... C=1, gamma=0.1, score=0.910, total=   0.1s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ...................... C=1, gamma=0.1, score=0.882, total=   0.1s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.912, total=   0.1s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.936, total=   0.2s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.897, total=   0.1s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.910, total=   0.1s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.882, total=   0.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.912, total=   0.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.936, total=   0.2s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.897, total=   0.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.910, total=   0.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.882, total=   0.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.912, total=   0.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.936, total=   0.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.897, total=   0.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.910, total=   0.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.882, total=   0.1s
# [CV] C=10, gamma=1 ...................................................
# [CV] ....................... C=10, gamma=1, score=0.897, total=   0.1s
# [CV] C=10, gamma=1 ...................................................
# [CV] ....................... C=10, gamma=1, score=0.908, total=   0.2s
# [CV] C=10, gamma=1 ...................................................
# [CV] ....................... C=10, gamma=1, score=0.884, total=   0.1s
# [CV] C=10, gamma=1 ...................................................
# [CV] ....................... C=10, gamma=1, score=0.888, total=   0.1s
# [CV] C=10, gamma=1 ...................................................
# [CV] ....................... C=10, gamma=1, score=0.886, total=   0.2s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ..................... C=10, gamma=0.1, score=0.897, total=   0.1s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ..................... C=10, gamma=0.1, score=0.908, total=   0.1s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ..................... C=10, gamma=0.1, score=0.884, total=   0.1s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ..................... C=10, gamma=0.1, score=0.888, total=   0.1s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ..................... C=10, gamma=0.1, score=0.886, total=   0.2s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.897, total=   0.1s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.908, total=   0.2s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.884, total=   0.1s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.888, total=   0.1s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.886, total=   0.2s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.897, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.908, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.884, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.888, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.886, total=   0.2s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.897, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.908, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.884, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.888, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.886, total=   0.2s
# [CV] C=100, gamma=1 ..................................................
# [CV] ...................... C=100, gamma=1, score=0.893, total=   0.1s
# [CV] C=100, gamma=1 ..................................................
# [CV] ...................... C=100, gamma=1, score=0.906, total=   0.2s
# [CV] C=100, gamma=1 ..................................................
# [CV] ...................... C=100, gamma=1, score=0.884, total=   0.1s
# [CV] C=100, gamma=1 ..................................................
# [CV] ...................... C=100, gamma=1, score=0.888, total=   0.1s
# [CV] C=100, gamma=1 ..................................................
# [CV] ...................... C=100, gamma=1, score=0.886, total=   0.2s
# [CV] C=100, gamma=0.1 ................................................
# [CV] .................... C=100, gamma=0.1, score=0.893, total=   0.1s
# [CV] C=100, gamma=0.1 ................................................
# [CV] .................... C=100, gamma=0.1, score=0.906, total=   0.2s
# [CV] C=100, gamma=0.1 ................................................
# [CV] .................... C=100, gamma=0.1, score=0.884, total=   0.1s
# [CV] C=100, gamma=0.1 ................................................
# [CV] .................... C=100, gamma=0.1, score=0.888, total=   0.1s
# [CV] C=100, gamma=0.1 ................................................
# [CV] .................... C=100, gamma=0.1, score=0.886, total=   0.2s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................... C=100, gamma=0.01, score=0.893, total=   0.1s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................... C=100, gamma=0.01, score=0.906, total=   0.2s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................... C=100, gamma=0.01, score=0.884, total=   0.1s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................... C=100, gamma=0.01, score=0.888, total=   0.1s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................... C=100, gamma=0.01, score=0.886, total=   0.2s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.893, total=   0.1s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.906, total=   0.2s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.884, total=   0.1s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.888, total=   0.1s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.886, total=   0.2s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.893, total=   0.1s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.906, total=   0.1s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.884, total=   0.1s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.888, total=   0.1s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.886, total=   0.2s
# [CV] C=1000, gamma=1 .................................................
# [CV] ..................... C=1000, gamma=1, score=0.893, total=   0.1s
# [CV] C=1000, gamma=1 .................................................
# [CV] ..................... C=1000, gamma=1, score=0.906, total=   0.2s
# [CV] C=1000, gamma=1 .................................................
# [CV] ..................... C=1000, gamma=1, score=0.884, total=   0.1s
# [CV] C=1000, gamma=1 .................................................
# [CV] ..................... C=1000, gamma=1, score=0.888, total=   0.1s
# [CV] C=1000, gamma=1 .................................................
# [CV] ..................... C=1000, gamma=1, score=0.886, total=   0.2s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ................... C=1000, gamma=0.1, score=0.893, total=   0.1s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ................... C=1000, gamma=0.1, score=0.906, total=   0.1s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ................... C=1000, gamma=0.1, score=0.884, total=   0.1s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ................... C=1000, gamma=0.1, score=0.888, total=   0.1s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ................... C=1000, gamma=0.1, score=0.886, total=   0.2s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] .................. C=1000, gamma=0.01, score=0.893, total=   0.1s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] .................. C=1000, gamma=0.01, score=0.906, total=   0.2s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] .................. C=1000, gamma=0.01, score=0.884, total=   0.1s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] .................. C=1000, gamma=0.01, score=0.888, total=   0.1s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] .................. C=1000, gamma=0.01, score=0.886, total=   0.2s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.893, total=   0.1s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.906, total=   0.2s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.884, total=   0.1s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.888, total=   0.1s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.886, total=   0.2s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.893, total=   0.1s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.906, total=   0.2s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.884, total=   0.1s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.888, total=   0.1s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.886, total=   0.2s
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed:   17.3s finished
# GridSearchCV(estimator=SVC(C=1, kernel='linear'),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001]},
#              verbose=3)

# %%
grid_multi.best_params_
# Out:
# {'C': 0.1, 'gamma': 1}

# %%
# get support vectors
gridvector_multi = SVC(C=0.1, kernel='linear', degree=3, gamma=1, coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', break_ties=False, random_state=None)
gridvector_multi.fit(X_train,y_train)
NumSV = gridvector_multi.support_vectors_
NumSV.shape
# Out:
# (691, 128)

# %%
predictions_grid_multi = grid_multi.predict(X_test)

# %%
print(confusion_matrix(y_test, predictions_grid_multi))
print('\n')
print(classification_report(y_test,predictions_grid_multi))
# Out:
# [[285   1  14   2]
#  [  2 246  12   9]
#  [  5  11 234   7]
#  [  3  26   4 263]]
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95       302
#          1.0       0.87      0.91      0.89       269
#          2.0       0.89      0.91      0.90       257
#          3.0       0.94      0.89      0.91       296
#
#     accuracy                           0.91      1124
#    macro avg       0.91      0.91      0.91      1124
# weighted avg       0.92      0.91      0.91      1124

# %%
# testing the held_out data
predictions_heldout_multi = grid_multi.predict(X_heldout)
print(confusion_matrix(y_heldout, predictions_heldout_multi))
print('\n')
print(classification_report(y_heldout, predictions_heldout_multi))
# Out:
# [[44  2  4  0]
#  [ 0 49  1  0]
#  [ 1  4 45  0]
#  [ 0 16  0 34]]
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.88      0.93        50
#          1.0       0.69      0.98      0.81        50
#          2.0       0.90      0.90      0.90        50
#          3.0       1.00      0.68      0.81        50
#
#     accuracy                           0.86       200
#    macro avg       0.89      0.86      0.86       200
# weighted avg       0.89      0.86      0.86       200

# %% [markdown]
# #  Performing multi-classifier using other methods: ..., NN, ...
